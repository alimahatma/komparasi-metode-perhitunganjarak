# %%
import numpy as np
import pandas as pd
import glob

# %%
df1 = pd.read_csv("01-jan-2021.csv")
df2 = pd.read_csv("02-feb-2021.csv")
df3 = pd.read_csv("03-maret-2021.csv")
df4 = pd.read_csv("04-april-2021.csv")
df5 = pd.read_csv("05-mei-2021.csv")
df6 = pd.read_csv("06-jun-2021.csv")
df7 = pd.read_csv("07-juli-2021.csv")
df8 = pd.read_csv("08-ags-2021.csv")
df9 = pd.read_csv("09-sep-2021.csv")
df10 = pd.read_csv("10-okt-2021.csv")
df11 = pd.read_csv("11-nov-2021.csv")
df12 = pd.read_csv("12-des-2021.csv")
df13 = pd.read_csv("2020/1-jan-2020.csv")
df14 = pd.read_csv("2020/2-feb-2020.csv")
df15 = pd.read_csv("2020/3-mar-2020.csv")
df16 = pd.read_csv("2020/4-april-2020.csv")
df17 = pd.read_csv("2020/5-mei-2020.csv")
df18 = pd.read_csv("2020/6-jun-2020.csv")
df19 = pd.read_csv("2020/7-jul-2020.csv")
df20 = pd.read_csv("2020/8-gst-2020.csv")
df21 = pd.read_csv("2020/9-sep-2020.csv")
df22 = pd.read_csv("2020/10-okt-2020.csv")
df23 = pd.read_csv("2020/11-nov-2020.csv")
df24 = pd.read_csv("2020/12-des-2020.csv")

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24]

# %%
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
result
# Out:
#      tahun  bulan            destinasi_wisata  jumlah
# 0     2021      1     Taman Impian Jaya Ancol       0
# 1     2021      1  Taman Mini Indonesia Indah       0
# 2     2021      1    Taman Margasatwa Ragunan       0
# 3     2021      1            Monumen Nasional       0
# 4     2021      1             Museum Nasional       4
# ..     ...    ...                         ...     ...
# 475   2020     12            PBB Setu babakan       0
# 476   2020     12             Museum Prasasti       0
# 477   2020     12                 Planetarium       0
# 478   2020     12             Rumah si Pitung       0
# 479   2020     12            Kawasan Kota Tua       0
#
# [480 rows x 4 columns]

# %%
datasets = result
datasets.head()
# Out:
#    tahun  bulan            destinasi_wisata  jumlah
# 0   2021      1     Taman Impian Jaya Ancol       0
# 1   2021      1  Taman Mini Indonesia Indah       0
# 2   2021      1    Taman Margasatwa Ragunan       0
# 3   2021      1            Monumen Nasional       0
# 4   2021      1             Museum Nasional       4

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tahun             480 non-null    int64
#  1   bulan             480 non-null    int64
#  2   destinasi_wisata  480 non-null    object
#  3   jumlah            480 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.1+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
group_2021 = datasets.groupby('destinasi_wisata')['jumlah'].sum().reset_index()

# %%
group_2021
# Out:
#                 destinasi_wisata  jumlah
# 0               Kawasan Kota Tua   18621
# 1               Kepulauan Seribu    5211
# 2               Monumen Nasional    4339
# 3                  Museum Bahari     640
# 4                   Museum Joang      33
# 5                Museum Nasional    5974
# 6                Museum Prasasti      80
# 7          Museum Satria Mandala       0
# 8         Museum Sejarah Jakarta    4017
# 9   Museum Seni Rupa dan Keramik     866
# 10                Museum Tekstil     579
# 11                 Museum Wayang    3026
# 12              PBB Setu babakan      12
# 13        Pelabuhan Sunda Kelapa     180
# 14                   Planetarium       0
# 15               Rumah si Pitung       1
# 16        Taman Arkeologi Onrust       9
# 17       Taman Impian Jaya Ancol    1076
# 18      Taman Margasatwa Ragunan    1501
# 19    Taman Mini Indonesia Indah       0

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='destinasi_wisata', y='jumlah', data=group_2021, palette='viridis')
plt.title('Total Jumlah Kunjungan ke Destinasi Wisata Mancanegara 20020-2021')
plt.xlabel('Destinasi Wisata')
plt.ylabel('Total Jumlah Kunjungan')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analisa Deskriptif

# %%
descrivtif_stat = datasets.describe()

# %%
print(descrivtif_stat)
# Out:
#              tahun       bulan       jumlah
# count   480.000000  480.000000   480.000000
# mean   2020.500000    6.500000    96.177083
# std       0.500522    3.455654   503.191609
# min    2020.000000    1.000000     0.000000
# 25%    2020.000000    3.750000     0.000000
# 50%    2020.500000    6.500000     0.000000
# 75%    2021.000000    9.250000    11.000000
# max    2021.000000   12.000000  7123.000000

# %% [markdown]
# # Visualisasi

# %%
sns.set(style='whitegrid', palette='viridis')
plt.figure(figsize=(8, 6))
sns.histplot(datasets['jumlah'], bins=10, edgecolor='black')
plt.title("Distribusi Jumlah Kunjungan Wisatawan Mancanegara")
plt.xlabel("Jumlah Kunjungan")
plt.ylabel("Frekuensi")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(datasets['jumlah'], datasets['destinasi_wisata'], c='blue', alpha=0.7)
plt.title('Scatter Plot: Jumlah Kunjungan vs Destinasi Wisata')
plt.xlabel('Jumlah Kunjungan')
plt.ylabel('Destinasi Wisata')
plt.grid(True)
plt.show()

# %%
group_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   destinasi_wisata  20 non-null     object
#  1   jumlah            20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
data = group_2021['jumlah']
plt.figure(figsize=(8,6))
box = plt.boxplot(data)

plt.title('Box Plot Jumlah Kunjungan Wisatawan')
plt.ylabel('Jumlah Kunjungan Kunjungan Wisatawan Mancanegara')
plt.show()

# %%
jumlah_kunjungan_per_destinasi = datasets.groupby('destinasi_wisata')['jumlah'].sum()

# %%
ax = jumlah_kunjungan_per_destinasi.plot(kind='bar', color='purple')

for i, v in enumerate(jumlah_kunjungan_per_destinasi):
    ax.text(i, v + 5, str(v), ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.xlabel("Destinasi Wisata")
plt.ylabel("Jumlah Kunjungan")

plt.show()

# %%
datasets_copy = datasets.copy()

# %% [markdown]
# # UJI KORELASI

# %%
unique_des = datasets_copy['destinasi_wisata'].unique()
mapping = {dest: idx+1 for idx, dest in enumerate(unique_des)}

datasets_copy['destinasi_wisata'] = datasets['destinasi_wisata'].replace(mapping)

df = datasets_copy.iloc[:, 1:4]

corr_matrix = df.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriks Korelasi Antar Atribut")
plt.show()

# %% [markdown]
# # DETEKSI OUTLIER

# %%
df_o = datasets_copy['jumlah']
df_o = pd.DataFrame(df_o)
df_o
# Out:
#      jumlah
# 0         0
# 1         0
# 2         0
# 3         0
# 4         4
# ..      ...
# 475       0
# 476       0
# 477       0
# 478       0
# 479       0
#
# [480 rows x 1 columns]

# %%
# Hitung Q1 dan Q3
Q1 = df_o['jumlah'].quantile(0.25)
Q3 = df_o['jumlah'].quantile(0.75)

# Hitung IQR
IQR = Q3 - Q1

# Tentukan batas atas dan batas bawah
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR



# Deteksi outlier
outliers = df_o[(df_o['jumlah'] < lower_bound) | (df_o['jumlah'] > upper_bound)]

print(outliers)
# Out:
#      jumlah
# 14      129
# 19       49
# 34      106
# 39      108
# 42       44
# ..      ...
# 454     138
# 459      45
# 462      31
# 468      30
# 474     214
#
# [96 rows x 1 columns]

# %%
# Buat scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(range(len(df_o)), df_o['jumlah'], c='blue', label='Data')
plt.scatter(outliers.index, outliers['jumlah'], c='red', label='Outlier')
plt.title('Scatter Plot untuk Mendeteksi Outlier')
plt.xlabel('Indeks Data')
plt.ylabel('Nilai')
plt.legend()
plt.show()

# %%
datasets_normalized = (df_o - df_o.min()) / (df_o.max() - df_o.min())
df_o = datasets_normalized

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=5, min_samples=2)

dbscan.fit(df_o)
# Out:
# DBSCAN(eps=5, min_samples=2)

# %%
outliers = df_o[dbscan.labels_ == 0]

# %%
print(outliers)
# Out:
#        jumlah
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000562
# ..        ...
# 475  0.000000
# 476  0.000000
# 477  0.000000
# 478  0.000000
# 479  0.000000
#
# [480 rows x 1 columns]

# %%
df_o = outliers

# %%
df_o
# Out:
#        jumlah
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000562
# ..        ...
# 475  0.000000
# 476  0.000000
# 477  0.000000
# 478  0.000000
# 479  0.000000
#
# [480 rows x 1 columns]

# %%
plt.figure(figsize=(6, 4))
plt.scatter(range(len(df_o)), df_o['jumlah'], c='blue', label='Data')
plt.scatter(outliers.index, outliers['jumlah'], c='red', label='Outlier')
plt.title('Scatter Plot untuk Mendeteksi Outlier')
plt.xlabel('Indeks Data')
plt.ylabel('Nilai')
plt.legend()
plt.show()

# %%
datasets['Jumlah'] = df_o

# %%
datasets_copy2 = datasets.copy()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
label_encoder = LabelEncoder()

# %%
df = datasets.copy()

# %%
destinasi = df['destinasi_wisata'] 
jumlah = df['Jumlah']

data = pd.concat([df['destinasi_wisata'], df['Jumlah']], axis=1)

# %%
data['destinasi'] = label_encoder.fit_transform(data['destinasi_wisata'])

X = data[['Jumlah','destinasi']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
inertia_values = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X[['Jumlah', 'destinasi']])
    inertia_values.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_values, marker='o')
plt.xlabel('Jumlah Cluster')
plt.ylabel('Inersia')
plt.title('Metode Elbow untuk Menentukan Jumlah Cluster Optimal')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
from sklearn.metrics import pairwise_distances_argmin_min
from scipy.spatial.distance import cdist

k = 5
np.random.seed(0)
initial_centers = X_scaled[np.random.choice(range(len(X_scaled)), k, replace=False)]

for i in range(100):  # Jumlah iterasi maksimum
    # Hitung jarak Manhattan antara setiap data dan pusat cluster
    distances = cdist(X_scaled, initial_centers, metric='cityblock')  # 'cityblock' adalah metrik Manhattan
    # Assign setiap data ke cluster dengan pusat terdekat
    labels = np.argmin(distances, axis=1)
    # Hitung pusat baru untuk setiap cluster
    new_centers = np.array([X_scaled[labels == j].mean(axis=0) for j in range(k)])
    # Cek apakah pusat cluster telah konvergen
    if np.all(initial_centers == new_centers):
        break
    initial_centers = new_centers
    
labels = np.argmin(distances, axis=1)

# Dapatkan pusat cluster
cluster_centers = new_centers

# Dapatkan titik data yang paling dekat dengan pusat cluster
closest_points, _ = pairwise_distances_argmin_min(X_scaled, cluster_centers)

# %%
df['Cluster'] = kmeans.labels_

# %%
print(df)
# Out:
#      tahun  bulan            destinasi_wisata  jumlah    Jumlah  Cluster
# 0     2021      1     Taman Impian Jaya Ancol       0  0.000000        2
# 1     2021      1  Taman Mini Indonesia Indah       0  0.000000        2
# 2     2021      1    Taman Margasatwa Ragunan       0  0.000000        2
# 3     2021      1            Monumen Nasional       0  0.000000        1
# 4     2021      1             Museum Nasional       4  0.000562        5
# ..     ...    ...                         ...     ...       ...      ...
# 475   2020     12            PBB Setu babakan       0  0.000000        0
# 476   2020     12             Museum Prasasti       0  0.000000        5
# 477   2020     12                 Planetarium       0  0.000000        9
# 478   2020     12             Rumah si Pitung       0  0.000000        4
# 479   2020     12            Kawasan Kota Tua       0  0.000000        7
#
# [480 rows x 6 columns]

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')
plt.xlabel('Jumlah Wisatawan Mancanegara')
plt.ylabel('Destinasi Wisata')
plt.title('Clustering Produk Berdasarkan Jumlah Pengunjung dan Destinasi Wisata')
plt.legend()
plt.show()

# %%
cluster_tables = []

for cluster_label in range(k):
    cluster_data = df[df['Cluster'] == cluster_label].drop(columns=['Cluster'])
    cluster_tables.append(cluster_data)

# %%
for i, cluster_data in enumerate(cluster_tables):
    print(f"Cluster {i + 1}:")
    print(cluster_data)
    print()
# Out:
# Cluster 1:
#      tahun  bulan  destinasi_wisata  jumlah    Jumlah
# 10    2021      1     Museum Wayang       6  0.000842
# 15    2021      1  PBB Setu babakan       0  0.000000
# 30    2021      2     Museum Wayang      17  0.002387
# 35    2021      2  PBB Setu babakan       0  0.000000
# 50    2021      3     Museum Wayang      40  0.005616
# 55    2021      3  PBB Setu babakan       0  0.000000
# 70    2021      4     Museum Wayang      20  0.002808
# 75    2021      4  PBB Setu babakan       0  0.000000
# 90    2021      5     Museum Wayang      57  0.008002
# 95    2021      5  PBB Setu babakan       0  0.000000
# 110   2021      6     Museum Wayang      55  0.007721
# 115   2021      6  PBB Setu babakan       0  0.000000
# 130   2021      7     Museum Wayang       0  0.000000
# 135   2021      7  PBB Setu babakan       0  0.000000
# 150   2021      8     Museum Wayang       0  0.000000
# 155   2021      8  PBB Setu babakan       0  0.000000
# 170   2021      9     Museum Wayang       0  0.000000
# 175   2021      9  PBB Setu babakan       0  0.000000
# 190   2021     10     Museum Wayang      36  0.005054
# 195   2021     10  PBB Setu babakan       0  0.000000
# 210   2021     12     Museum Wayang      59  0.008283
# 215   2021     12  PBB Setu babakan       0  0.000000
# 230   2021     11     Museum Wayang      98  0.013758
# 235   2021     11  PBB Setu babakan       0  0.000000
# 250   2020      1     Museum Wayang     865  0.121438
# 255   2020      1  PBB Setu babakan       2  0.000281
# 270   2020      2     Museum Wayang    1006  0.141233
# 275   2020      2  PBB Setu babakan      10  0.001404
# 290   2020      3     Museum Wayang     648  0.090973
# 295   2020      3  PBB Setu babakan       0  0.000000
# 310   2020      4     Museum Wayang       0  0.000000
# 315   2020      4  PBB Setu babakan       0  0.000000
# 330   2020      5     Museum Wayang       0  0.000000
# 335   2020      5  PBB Setu babakan       0  0.000000
# 350   2020      6     Museum Wayang      18  0.002527
# 355   2020      6  PBB Setu babakan       0  0.000000
# 370   2020      7     Museum Wayang      11  0.001544
# 375   2020      7  PBB Setu babakan       0  0.000000
# 390   2020      8     Museum Wayang      28  0.003931
# 395   2020      8  PBB Setu babakan       0  0.000000
# 410   2020      9     Museum Wayang       4  0.000562
# 415   2020      9  PBB Setu babakan       0  0.000000
# 430   2020     10     Museum Wayang      11  0.001544
# 435   2020     10  PBB Setu babakan       0  0.000000
# 450   2020     11     Museum Wayang      47  0.006598
# 455   2020     11  PBB Setu babakan       0  0.000000
# 470   2020     12     Museum Wayang       0  0.000000
# 475   2020     12  PBB Setu babakan       0  0.000000
#
# Cluster 2:
#      tahun  bulan  destinasi_wisata  jumlah    Jumlah
# 3     2021      1  Monumen Nasional       0  0.000000
# 23    2021      2  Monumen Nasional       0  0.000000
# 43    2021      3  Monumen Nasional       0  0.000000
# 63    2021      4  Monumen Nasional       0  0.000000
# 83    2021      5  Monumen Nasional       0  0.000000
# 103   2021      6  Monumen Nasional       0  0.000000
# 123   2021      7  Monumen Nasional       0  0.000000
# 143   2021      8  Monumen Nasional       0  0.000000
# 163   2021      9  Monumen Nasional       0  0.000000
# 183   2021     10  Monumen Nasional       0  0.000000
# 203   2021     12  Monumen Nasional       0  0.000000
# 223   2021     11  Monumen Nasional       0  0.000000
# 243   2020      1  Monumen Nasional    2070  0.290608
# 263   2020      2  Monumen Nasional    1689  0.237119
# 283   2020      3  Monumen Nasional     580  0.081426
# 303   2020      4  Monumen Nasional       0  0.000000
# 323   2020      5  Monumen Nasional       0  0.000000
# 343   2020      6  Monumen Nasional       0  0.000000
# 363   2020      7  Monumen Nasional       0  0.000000
# 383   2020      8  Monumen Nasional       0  0.000000
# 403   2020      9  Monumen Nasional       0  0.000000
# 423   2020     10  Monumen Nasional       0  0.000000
# 443   2020     11  Monumen Nasional       0  0.000000
# 463   2020     12  Monumen Nasional       0  0.000000
#
# Cluster 3:
#      tahun  bulan            destinasi_wisata  jumlah    Jumlah
# 0     2021      1     Taman Impian Jaya Ancol       0  0.000000
# 1     2021      1  Taman Mini Indonesia Indah       0  0.000000
# 2     2021      1    Taman Margasatwa Ragunan       0  0.000000
# 20    2021      2     Taman Impian Jaya Ancol       0  0.000000
# 21    2021      2  Taman Mini Indonesia Indah       0  0.000000
# ..     ...    ...                         ...     ...       ...
# 441   2020     11  Taman Mini Indonesia Indah       0  0.000000
# 442   2020     11    Taman Margasatwa Ragunan      40  0.005616
# 460   2020     12     Taman Impian Jaya Ancol       0  0.000000
# 461   2020     12  Taman Mini Indonesia Indah       0  0.000000
# 462   2020     12    Taman Margasatwa Ragunan      31  0.004352
#
# [72 rows x 5 columns]
#
# Cluster 4:
#      tahun  bulan        destinasi_wisata  jumlah    Jumlah
# 5     2021      1   Museum Satria Mandala       0  0.000000
# 6     2021      1  Museum Sejarah Jakarta       0  0.000000
# 25    2021      2   Museum Satria Mandala       0  0.000000
# 26    2021      2  Museum Sejarah Jakarta       0  0.000000
# 45    2021      3   Museum Satria Mandala       0  0.000000
# 46    2021      3  Museum Sejarah Jakarta       0  0.000000
# 65    2021      4   Museum Satria Mandala       0  0.000000
# 66    2021      4  Museum Sejarah Jakarta       0  0.000000
# 85    2021      5   Museum Satria Mandala       0  0.000000
# 86    2021      5  Museum Sejarah Jakarta       0  0.000000
# 105   2021      6   Museum Satria Mandala       0  0.000000
# 106   2021      6  Museum Sejarah Jakarta       0  0.000000
# 125   2021      7   Museum Satria Mandala       0  0.000000
# 126   2021      7  Museum Sejarah Jakarta       0  0.000000
# 145   2021      8   Museum Satria Mandala       0  0.000000
# 146   2021      8  Museum Sejarah Jakarta       0  0.000000
# 165   2021      9   Museum Satria Mandala       0  0.000000
# 166   2021      9  Museum Sejarah Jakarta       0  0.000000
# 185   2021     10   Museum Satria Mandala       0  0.000000
# 186   2021     10  Museum Sejarah Jakarta       0  0.000000
# 205   2021     12   Museum Satria Mandala       0  0.000000
# 206   2021     12  Museum Sejarah Jakarta      35  0.004914
# 225   2021     11   Museum Satria Mandala       0  0.000000
# 226   2021     11  Museum Sejarah Jakarta       0  0.000000
# 245   2020      1   Museum Satria Mandala       0  0.000000
# 246   2020      1  Museum Sejarah Jakarta    1831  0.257055
# 265   2020      2   Museum Satria Mandala       0  0.000000
# 266   2020      2  Museum Sejarah Jakarta    1755  0.246385
# 285   2020      3   Museum Satria Mandala       0  0.000000
# 286   2020      3  Museum Sejarah Jakarta     389  0.054612
# 305   2020      4   Museum Satria Mandala       0  0.000000
# 306   2020      4  Museum Sejarah Jakarta       0  0.000000
# 325   2020      5   Museum Satria Mandala       0  0.000000
# 326   2020      5  Museum Sejarah Jakarta       0  0.000000
# 345   2020      6   Museum Satria Mandala       0  0.000000
# 346   2020      6  Museum Sejarah Jakarta       3  0.000421
# 365   2020      7   Museum Satria Mandala       0  0.000000
# 366   2020      7  Museum Sejarah Jakarta       0  0.000000
# 385   2020      8   Museum Satria Mandala       0  0.000000
# 386   2020      8  Museum Sejarah Jakarta       0  0.000000
# 405   2020      9   Museum Satria Mandala       0  0.000000
# 406   2020      9  Museum Sejarah Jakarta       2  0.000281
# 425   2020     10   Museum Satria Mandala       0  0.000000
# 426   2020     10  Museum Sejarah Jakarta       2  0.000281
# 445   2020     11   Museum Satria Mandala       0  0.000000
# 446   2020     11  Museum Sejarah Jakarta       0  0.000000
# 465   2020     12   Museum Satria Mandala       0  0.000000
# 466   2020     12  Museum Sejarah Jakarta       0  0.000000
#
# Cluster 5:
#      tahun  bulan        destinasi_wisata  jumlah    Jumlah
# 12    2021      1  Taman Arkeologi Onrust       0  0.000000
# 18    2021      1         Rumah si Pitung       0  0.000000
# 32    2021      2  Taman Arkeologi Onrust       0  0.000000
# 38    2021      2         Rumah si Pitung       0  0.000000
# 52    2021      3  Taman Arkeologi Onrust       0  0.000000
# 58    2021      3         Rumah si Pitung       0  0.000000
# 72    2021      4  Taman Arkeologi Onrust       0  0.000000
# 78    2021      4         Rumah si Pitung       0  0.000000
# 92    2021      5  Taman Arkeologi Onrust       0  0.000000
# 98    2021      5         Rumah si Pitung       0  0.000000
# 112   2021      6  Taman Arkeologi Onrust       0  0.000000
# 118   2021      6         Rumah si Pitung       0  0.000000
# 132   2021      7  Taman Arkeologi Onrust       0  0.000000
# 138   2021      7         Rumah si Pitung       0  0.000000
# 152   2021      8  Taman Arkeologi Onrust       0  0.000000
# 158   2021      8         Rumah si Pitung       0  0.000000
# 172   2021      9  Taman Arkeologi Onrust       0  0.000000
# 178   2021      9         Rumah si Pitung       0  0.000000
# 192   2021     10  Taman Arkeologi Onrust       0  0.000000
# 198   2021     10         Rumah si Pitung       0  0.000000
# 212   2021     12  Taman Arkeologi Onrust       0  0.000000
# 218   2021     12         Rumah si Pitung       0  0.000000
# 232   2021     11  Taman Arkeologi Onrust       0  0.000000
# 238   2021     11         Rumah si Pitung       0  0.000000
# 252   2020      1  Taman Arkeologi Onrust       1  0.000140
# 258   2020      1         Rumah si Pitung       0  0.000000
# 272   2020      2  Taman Arkeologi Onrust       4  0.000562
# 278   2020      2         Rumah si Pitung       0  0.000000
# 292   2020      3  Taman Arkeologi Onrust       0  0.000000
# 298   2020      3         Rumah si Pitung       0  0.000000
# 312   2020      4  Taman Arkeologi Onrust       0  0.000000
# 318   2020      4         Rumah si Pitung       0  0.000000
# 332   2020      5  Taman Arkeologi Onrust       0  0.000000
# 338   2020      5         Rumah si Pitung       0  0.000000
# 352   2020      6  Taman Arkeologi Onrust       0  0.000000
# 358   2020      6         Rumah si Pitung       0  0.000000
# 372   2020      7  Taman Arkeologi Onrust       0  0.000000
# 378   2020      7         Rumah si Pitung       1  0.000140
# 392   2020      8  Taman Arkeologi Onrust       0  0.000000
# 398   2020      8         Rumah si Pitung       0  0.000000
# 412   2020      9  Taman Arkeologi Onrust       0  0.000000
# 418   2020      9         Rumah si Pitung       0  0.000000
# 432   2020     10  Taman Arkeologi Onrust       0  0.000000
# 438   2020     10         Rumah si Pitung       0  0.000000
# 452   2020     11  Taman Arkeologi Onrust       4  0.000562
# 458   2020     11         Rumah si Pitung       0  0.000000
# 472   2020     12  Taman Arkeologi Onrust       0  0.000000
# 478   2020     12         Rumah si Pitung       0  0.000000

# %%
df_clustered = df[['destinasi_wisata', 'Cluster']]
summary_table = df.groupby('Cluster')['Jumlah'].describe()
summary_table = summary_table.join(df_clustered.groupby('Cluster')['destinasi_wisata'].apply(lambda x: ', '.join(x)))
pd.set_option('display.max_columns', None)
print(summary_table)
# Out:
#          count      mean       std  min       25%       50%       75%  \
# Cluster
# 0         48.0  0.008886  0.029065  0.0  0.000000  0.000000  0.002597
# 1         24.0  0.025381  0.075713  0.0  0.000000  0.000000  0.000000
# 2         72.0  0.005025  0.014426  0.0  0.000000  0.000000  0.000526
# 3         48.0  0.011749  0.051191  0.0  0.000000  0.000000  0.000000
# 4         48.0  0.000029  0.000116  0.0  0.000000  0.000000  0.000000
# 5         48.0  0.017707  0.069214  0.0  0.000000  0.000000  0.002703
# 6         48.0  0.004226  0.010149  0.0  0.000000  0.000281  0.001860
# 7         48.0  0.069704  0.187892  0.0  0.006177  0.018742  0.034150
# 8         48.0  0.001968  0.006296  0.0  0.000000  0.000000  0.001299
# 9         48.0  0.000526  0.002613  0.0  0.000000  0.000000  0.000000
#
#               max                                   destinasi_wisata
# Cluster
# 0        0.141233  Museum Wayang, PBB Setu babakan, Museum Wayang...
# 1        0.290608  Monumen Nasional, Monumen Nasional, Monumen Na...
# 2        0.072441  Taman Impian Jaya Ancol, Taman Mini Indonesia ...
# 3        0.257055  Museum Satria Mandala, Museum Sejarah Jakarta,...
# 4        0.000562  Taman Arkeologi Onrust, Rumah si Pitung, Taman...
# 5        0.403903  Museum Nasional, Museum Prasasti, Museum Nasio...
# 6        0.043802  Museum Tekstil, Museum Seni Rupa dan Keramik, ...
# 7        1.000000  Kepulauan Seribu, Kawasan Kota Tua, Kepulauan ...
# 8        0.038467  Museum Bahari, Museum Joang, Museum Bahari, Mu...
# 9        0.016145  Pelabuhan Sunda Kelapa, Planetarium, Pelabuhan...

# %%
summary_table.to_csv('summary_table.csv')

# %%
summary_table.to_excel('summary_table_E.xlsx', index=False)

# %% [markdown]
# # Silhouette Score

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, kmeans.labels_)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.6487818420930836

# %% [markdown]
# # Inertia (Within-Cluster Sum of Squares):

# %%
inertia = kmeans.inertia_
print(f"Inertia: {inertia}")
# Out:
# Inertia: 146.2009280361035

# %%
import matplotlib.pyplot as plt
plt.scatter(X['Jumlah'], X['destinasi'], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')
plt.xlabel('Jumlah Kunjungan Wisatawan Mancanegara')
plt.ylabel('Destinasi')
plt.title('Clustering Produk Berdasarkan Jumlah Kunjungan Wisatawan Mancanegara dan Destinasi Wisata ')
plt.legend()
plt.show()

# %% [markdown]
# # Davies-Bouldin Index:

# %%
from sklearn.metrics import davies_bouldin_score

b_index = davies_bouldin_score(X, kmeans.labels_)
print(f"Davies-Bouldin Index: {b_index}")
# Out:
# Davies-Bouldin Index: 0.47368137274429056
