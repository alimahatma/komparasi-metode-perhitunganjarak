# %%
import numpy as np
import pandas as pd
import glob

# %%
df1 = pd.read_csv("01-jan-2021.csv")
df2 = pd.read_csv("02-feb-2021.csv")
df3 = pd.read_csv("03-maret-2021.csv")
df4 = pd.read_csv("04-april-2021.csv")
df5 = pd.read_csv("05-mei-2021.csv")
df6 = pd.read_csv("06-jun-2021.csv")
df7 = pd.read_csv("07-juli-2021.csv")
df8 = pd.read_csv("08-ags-2021.csv")
df9 = pd.read_csv("09-sep-2021.csv")
df10 = pd.read_csv("10-okt-2021.csv")
df11 = pd.read_csv("11-nov-2021.csv")
df12 = pd.read_csv("12-des-2021.csv")
df13 = pd.read_csv("2020/1-jan-2020.csv")
df14 = pd.read_csv("2020/2-feb-2020.csv")
df15 = pd.read_csv("2020/3-mar-2020.csv")
df16 = pd.read_csv("2020/4-april-2020.csv")
df17 = pd.read_csv("2020/5-mei-2020.csv")
df18 = pd.read_csv("2020/6-jun-2020.csv")
df19 = pd.read_csv("2020/7-jul-2020.csv")
df20 = pd.read_csv("2020/8-gst-2020.csv")
df21 = pd.read_csv("2020/9-sep-2020.csv")
df22 = pd.read_csv("2020/10-okt-2020.csv")
df23 = pd.read_csv("2020/11-nov-2020.csv")
df24 = pd.read_csv("2020/12-des-2020.csv")

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24]

# %%
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
result
# Out:
#      tahun  bulan            destinasi_wisata  jumlah
# 0     2021      1     Taman Impian Jaya Ancol       0
# 1     2021      1  Taman Mini Indonesia Indah       0
# 2     2021      1    Taman Margasatwa Ragunan       0
# 3     2021      1            Monumen Nasional       0
# 4     2021      1             Museum Nasional       4
# ..     ...    ...                         ...     ...
# 475   2020     12            PBB Setu babakan       0
# 476   2020     12             Museum Prasasti       0
# 477   2020     12                 Planetarium       0
# 478   2020     12             Rumah si Pitung       0
# 479   2020     12            Kawasan Kota Tua       0
#
# [480 rows x 4 columns]

# %%
datasets = result
datasets.head()
# Out:
#    tahun  bulan            destinasi_wisata  jumlah
# 0   2021      1     Taman Impian Jaya Ancol       0
# 1   2021      1  Taman Mini Indonesia Indah       0
# 2   2021      1    Taman Margasatwa Ragunan       0
# 3   2021      1            Monumen Nasional       0
# 4   2021      1             Museum Nasional       4

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tahun             480 non-null    int64
#  1   bulan             480 non-null    int64
#  2   destinasi_wisata  480 non-null    object
#  3   jumlah            480 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.1+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
group_2021 = datasets.groupby('destinasi_wisata')['jumlah'].sum().reset_index()

# %%
group_2021
# Out:
#                 destinasi_wisata  jumlah
# 0               Kawasan Kota Tua   18621
# 1               Kepulauan Seribu    5211
# 2               Monumen Nasional    4339
# 3                  Museum Bahari     640
# 4                   Museum Joang      33
# 5                Museum Nasional    5974
# 6                Museum Prasasti      80
# 7          Museum Satria Mandala       0
# 8         Museum Sejarah Jakarta    4017
# 9   Museum Seni Rupa dan Keramik     866
# 10                Museum Tekstil     579
# 11                 Museum Wayang    3026
# 12              PBB Setu babakan      12
# 13        Pelabuhan Sunda Kelapa     180
# 14                   Planetarium       0
# 15               Rumah si Pitung       1
# 16        Taman Arkeologi Onrust       9
# 17       Taman Impian Jaya Ancol    1076
# 18      Taman Margasatwa Ragunan    1501
# 19    Taman Mini Indonesia Indah       0

# %%
plt.figure(figsize=(8, 8))
ax = sns.barplot(x='destinasi_wisata', y='jumlah', data=group_2021, palette='viridis')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=8, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.title('Total Jumlah Kunjungan ke Destinasi Wisata Jakarta Tahun 2021')
plt.xlabel('Destinasi Wisata')
plt.ylabel('Total Jumlah Kunjungan')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analisa Deskriptif

# %%
descrivtif_stat = datasets.describe()

# %%
print(descrivtif_stat)
# Out:
#              tahun       bulan       jumlah
# count   480.000000  480.000000   480.000000
# mean   2020.500000    6.500000    96.177083
# std       0.500522    3.455654   503.191609
# min    2020.000000    1.000000     0.000000
# 25%    2020.000000    3.750000     0.000000
# 50%    2020.500000    6.500000     0.000000
# 75%    2021.000000    9.250000    11.000000
# max    2021.000000   12.000000  7123.000000

# %% [markdown]
# # Visualisasi

# %%
sns.set(style='whitegrid', palette='viridis')
plt.figure(figsize=(8, 6))
sns.histplot(datasets['jumlah'], bins=10, edgecolor='black')
plt.title("Distribusi Jumlah Kunjungan")
plt.xlabel("Jumlah Kunjungan")
plt.ylabel("Frekuensi")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(datasets['jumlah'], datasets['destinasi_wisata'], c='blue', alpha=0.7)
plt.title('Scatter Plot: Destinasi Wisata vs Kunjungan Wisatawan Mancanegara')
plt.xlabel('Persebaran Wisatawan Mancanegera')
plt.ylabel('Destinasi Wisata')
plt.grid(True)
plt.show()

# %%
group_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   destinasi_wisata  20 non-null     object
#  1   jumlah            20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
data = group_2021['jumlah']
plt.figure(figsize=(8,6))
box = plt.boxplot(data)

plt.title('Box Plot Jumlah Kunjungan')
plt.ylabel('Jumlah Kunjungan')
plt.show()

# %%
jumlah_kunjungan_per_destinasi = datasets.groupby('destinasi_wisata')['jumlah'].sum()

# %%
plt.figure(figsize=(8, 6))
jumlah_kunjungan_per_destinasi.plot(kind='bar', color='purple')
plt.title('Jumlah Kunjungan per Destinasi Wisata')
plt.xlabel('Destinasi Wisata')
plt.ylabel('Jumlah Kunjungan')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
ax = jumlah_kunjungan_per_destinasi.plot(kind='bar', color='purple')

for i, v in enumerate(jumlah_kunjungan_per_destinasi):
    ax.text(i, v + 5, str(v), ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %%
datasets_copy = datasets.copy()

# %% [markdown]
# # UJI KORELASI

# %%
unique_des = datasets_copy['destinasi_wisata'].unique()
mapping = {dest: idx+1 for idx, dest in enumerate(unique_des)}

datasets_copy['destinasi_wisata'] = datasets['destinasi_wisata'].replace(mapping)

df = datasets_copy.iloc[:, 1:4]

corr_matrix = df.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriks Korelasi Antar Atribut")
plt.show()

# %% [markdown]
# # DETEKSI OUTLIER

# %%
df_o = datasets_copy['jumlah']
df_o = pd.DataFrame(df_o)
df_o
# Out:
#      jumlah
# 0         0
# 1         0
# 2         0
# 3         0
# 4         4
# ..      ...
# 475       0
# 476       0
# 477       0
# 478       0
# 479       0
#
# [480 rows x 1 columns]

# %%
# Hitung Q1 dan Q3
Q1 = df_o['jumlah'].quantile(0.25)
Q3 = df_o['jumlah'].quantile(0.75)

# Hitung IQR
IQR = Q3 - Q1

# Tentukan batas atas dan batas bawah
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR



# Deteksi outlier
outliers = df_o[(df_o['jumlah'] < lower_bound) | (df_o['jumlah'] > upper_bound)]

print(outliers)
# Out:
#      jumlah
# 14      129
# 19       49
# 34      106
# 39      108
# 42       44
# ..      ...
# 454     138
# 459      45
# 462      31
# 468      30
# 474     214
#
# [96 rows x 1 columns]

# %%
# Buat scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(range(len(df_o)), df_o['jumlah'], c='blue', label='Data')
plt.scatter(outliers.index, outliers['jumlah'], c='red', label='Outlier')
plt.title('Scatter Plot untuk Mendeteksi Outlier')
plt.xlabel('Indeks Data')
plt.ylabel('Nilai')
plt.legend()
plt.show()

# %%
datasets_normalized = (df_o - df_o.min()) / (df_o.max() - df_o.min())
df_o = datasets_normalized

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=5, min_samples=2)

dbscan.fit(df_o)
# Out:
# DBSCAN(eps=5, min_samples=2)

# %%
outliers = df_o[dbscan.labels_ == 0]

# %%
print(outliers)
# Out:
#        jumlah
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000562
# ..        ...
# 475  0.000000
# 476  0.000000
# 477  0.000000
# 478  0.000000
# 479  0.000000
#
# [480 rows x 1 columns]

# %%
df_o = outliers

# %%
df_o
# Out:
#        jumlah
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000562
# ..        ...
# 475  0.000000
# 476  0.000000
# 477  0.000000
# 478  0.000000
# 479  0.000000
#
# [480 rows x 1 columns]

# %%
plt.figure(figsize=(6, 4))
plt.scatter(range(len(df_o)), df_o['jumlah'], c='blue', label='Data')
plt.scatter(outliers.index, outliers['jumlah'], c='red', label='Outlier')
plt.title('Scatter Plot untuk Mendeteksi Outlier')
plt.xlabel('Indeks Data')
plt.ylabel('Nilai')
plt.legend()
plt.show()

# %%
datasets['Jumlah'] = df_o

# %%
datasets_copy2 = datasets.copy()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
label_encoder = LabelEncoder()

# %%
df = datasets.copy()

# %%
destinasi = df['destinasi_wisata'] 
jumlah = df['Jumlah']

data = pd.concat([df['destinasi_wisata'], df['Jumlah']], axis=1)

# %%
data['destinasi'] = label_encoder.fit_transform(data['destinasi_wisata'])

X = data[['Jumlah','destinasi']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
inertia_values = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X[['Jumlah', 'destinasi']])
    inertia_values.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_values, marker='o')
plt.xlabel('Jumlah Cluster')
plt.ylabel('Inersia')
plt.title('Metode Elbow untuk Menentukan Jumlah Cluster Optimal')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
from scipy.spatial.distance import cdist
from math import radians, sin, cos, sqrt, atan2
k = 5

# %%
data_rad = np.radians(X_scaled)

# %%
def haversine(coord1, coord2):
    # Radius bumi dalam kilometer
    R = 6371.0

    lat1, lon1 = coord1
    lat2, lon2 = coord2

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    return distance

# %%
kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
kmeans.fit(data_rad)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Mendapatkan pusat cluster dalam radian
cluster_centers_rad = kmeans.cluster_centers_

# %%
# Menghitung jarak Haversine antara titik data dan pusat cluster
distances = np.array([[haversine(data_point, center) for center in cluster_centers_rad] for data_point in data_rad])

# %%
cluster_labels = np.argmin(distances, axis=1)

# %%
# Visualisasi hasil clustering
cmap = plt.cm.viridis
norm = plt.Normalize(vmin=min(cluster_labels), vmax=max(cluster_labels))
scatter = plt.scatter(X_scaled[:, 1], X_scaled[:, 0], c=cluster_labels, cmap=cmap, norm=norm)

# Menambahkan pusat cluster
plt.scatter(cluster_centers_rad[:, 1], cluster_centers_rad[:, 0], s=200, c='red', label='Centroids')
# Menambahkan legenda
plt.legend(handles=scatter.legend_elements()[0], title="Clusters")

# Menambahkan label sumbu
plt.xlabel("Jumlah")
plt.ylabel("Destinasi")

# Menampilkan plot
plt.show()

# Output label cluster
print("Hasil Clustering K-Means:")
print(cluster_labels)
# Out:
# Hasil Clustering K-Means:
# [3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2
#  3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0
#  2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0
#  2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0
#  2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2
#  0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3
#  3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 4 4 0 4 0 2 0 0 2 3 0 4 0 2 3 3
#  1 3 3 3 4 4 0 4 0 2 0 0 2 3 0 2 0 2 3 3 1 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0
#  2 3 3 4 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3
#  0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0
#  0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0
#  0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2
#  2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2 3 3 3 2 2 0 0 0 2 0 0 2 3 0 2 0 2 3 3 2]

# %%
# summary_table.to_excel('summary_table.xlsx', index=False)

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, kmeans.labels_)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.35740926957319236

# %%
inertia = kmeans.inertia_
print(f"Inertia: {inertia}")
# Out:
# Inertia: 0.02632606431839715

# %%
import matplotlib.pyplot as plt
plt.scatter(X['Jumlah'], X['destinasi'], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')
plt.xlabel('Jumlah Kunjungan Wisatawan Mancanegara')
plt.ylabel('Produk_Kode')
plt.title('Clustering Produk Berdasarkan Jumlah Kunjungan Wisatawan Mancanegara dan Destinasi Wisata ')
plt.legend()
plt.show()

# %%
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, kmeans.labels_)
print(f"Davies-Bouldin Index: {db_index}")
# Out:
# Davies-Bouldin Index: 2.3892132981405214
